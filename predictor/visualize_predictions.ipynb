# %%
from keras_predictions import *
import pickle

# %%
df = pd.read_csv('../../merged_df.csv')

# %%
item_dict = get_predictions(df).process(2)

# %%
print("Top 5 Purchased Items For User")
print("------------------------------")
print_imgs(item_dict['bought'])

print("Top 5 Recommended Items For User")
print("--------------------------------")
print_imgs(item_dict['recommended'])
# Out:
# Top 5 Purchased Items For User
# ------------------------------
# Top 5 Recommended Items For User
# --------------------------------

# %%
with open('cold_start.pickle', 'rb') as handle:
    cold_start = pickle.load(handle)

# %%
print("Top 10 Cold Start Recommendations")
print("--------------------------------")
print_imgs_cold(cold_start['products'])
# Out:
# Top 10 Cold Start Recommendations
# --------------------------------
